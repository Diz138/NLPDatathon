# %%
# !pip install requests

import requests

# %%
# !pip install google-search-results

# %%
searchQuery = {
    "engine": "google_scholar_author",
    "api_key":"f75a6fb2e4f82d30ffb1867462c82fcd15131a8206308bc9b6152511a018ad7c",
    "author_id": "nF3uaG4AAAAJ",
    "q":"protein purification"

}
searchData = requests.get('https://serpapi.com/search.json?engine=google_scholar_author&author_id=nF3uaG4AAAAJ', searchQuery)
searchResults = searchData.json()
searchResults
# Out:
# {'search_metadata': {'id': '635d6c20303eb1ed26796013',
#   'status': 'Success',
#   'json_endpoint': 'https://serpapi.com/searches/3cbcf406183f1e69/635d6c20303eb1ed26796013.json',
#   'created_at': '2022-10-29 18:08:32 UTC',
#   'processed_at': '2022-10-29 18:08:32 UTC',
#   'google_scholar_author_url': 'https://scholar.google.com/citations?user=nF3uaG4AAAAJ&hl=en',
#   'raw_html_file': 'https://serpapi.com/searches/3cbcf406183f1e69/635d6c20303eb1ed26796013.html',
#   'total_time_taken': 0.67},
#  'search_parameters': {'engine': 'google_scholar_author',
#   'author_id': 'nF3uaG4AAAAJ',
#   'hl': 'en'},
#  'author': {'name': 'Andrew Zydney',
#   'affiliations': 'Professor Chemical Engineering, Penn State University',
#   'email': 'Verified email at psu.edu',
#   'interests': [{'title': 'Membrane separations',
#     'link': 'https://scholar.google.com/citations?view_op=search_authors&hl=en&mauthors=label:membrane_separations',
# ...

# %%
# Out:
# https://serpapi.com/search
